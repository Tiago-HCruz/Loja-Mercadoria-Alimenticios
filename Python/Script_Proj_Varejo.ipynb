# %% [markdown]
# <a href="https://colab.research.google.com/github/Tiago-HCruz/Loja-Mercadoria-Alimenticios/blob/main/Python/Script_Proj_Varejo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Projeto Mercado
#
# ---

# %% [markdown]
# Scripts para obter os banco de dados que será utilizado no projeto de mercado

# %% [markdown]
# ## Banco de dados **DB_Vendas**
# ---

# %% [markdown]
# ### Carregando as bibliotecas

# %%
# Importando as Bibliotecas
import pandas as pd
import numpy as np
import random
from google.colab import drive

# %% [markdown]
# ### Função que retorna um vetor com datas simuladas

# %% [markdown]
# A Função foi feita para retorna datas aleatorias do ano de 2025

# %%
## Função que retorna data aleatoria com base em um ano definido (nesse caso, 2025)
def Data(Ano, Tamanho):
  Data = pd.DataFrame({
      "Mes": [random.randrange(1, 13) for x in range(Tamanho)],
      "Ano": Ano
      })
  def Dia(variavel):
        if variavel == 1 or variavel == 3 or variavel == 5 or \
           variavel == 7 or variavel == 8 or variavel == 10 or \
           variavel == 12:
           Dias = random.randrange(1, 32)
        else:
           if variavel == 2:
              Dias = random.randrange(1, 29)
           else:
              Dias = random.randrange(1, 31)
        return Dias
  Data["Dia"] = Data.loc[:, ["Mes"]].\
                    apply(lambda x: Dia(x['Mes']),
                          axis=1)
  Data = ['/'.join([str(Data.loc[x,"Dia"]), str(Data.loc[x,"Mes"]), Ano]) for x in range(len(Data))]
  return Data

# %% [markdown]
# ### Função que retorna o banco de dados desejado

# %%
# Função que retorna o banco de dados
## Entradas:
### Replica: Quantidade de Compras para cada produto

## Vetores para retorna a variavél "Situação"
Sit = ["N","C"] # Situação
pop_vie = [95,5]

def DB_Vendas(Replica):
  # Quantidade de Produto (Id Produto)
  Produtos = 25
  for i in range(Produtos+1):

      random.seed(2030+i)

      df = pd.DataFrame({
      "Data": Data("2025",Replica),
      "Id Produto": [i]*Replica,
      "Id Cliente": [random.randrange(1, 19) for x in range(Replica)],
      "Quantidade": [random.randrange(1, 150) for x in range(Replica)],
      "Situação": random.choices(Sit, pop_vie, k=Replica),
      "Id Canal de Venda": [random.randrange(1, 3) for x in range(Replica)],
      "Id Vendedor": [random.randrange(1, 11) for x in range(Replica)]
      })

      ## Adicionando a variavel preço com base no Id Produto
      Min = [20,6,17,10,30,5,4,8,62,2,7,24,2,4,4,3,3,3,4,8,6,7,27,4,19]
      Max = [40,8,78,80,350,15,6,11,90,8,15,36,5,30,8,9,8,10,8,13,12,10,63,26,308]

      df["Preço"] = round(random.randrange(Min[i-1]*100, Max[i-1]*100)*0.01,2)

      ## Adicionando Preço Unitario
      df["Preço Unitario"] = df.loc[:,["Preço"]].\
                                  apply(lambda x: round(x*1.2,2),
                                        axis=1)

      # Concatenando os banco de dados Id Produtos
      if i >= 2:
          df3 = pd.concat([df3, df],
                    axis = 0,
                    ignore_index = True,
                    sort = False)
      else:
        df3 = df


  return df3


DB_Vendas = DB_Vendas(200)
DB_Vendas = DB_Vendas.iloc[:,[0,1,2,7,8,3,4,5,6]]

DB_Vendas
# Out:
#             Data  Id Produto  Id Cliente   Preço  Preço Unitario  Quantidade  \
# 0     13/11/2025           1           6   23.44           28.13          88
# 1       1/3/2025           1           7   23.44           28.13          51
# 2      10/6/2025           1          13   23.44           28.13         108
# 3      26/6/2025           1           3   23.44           28.13         135
# 4      12/5/2025           1          15   23.44           28.13          71
# ...          ...         ...         ...     ...             ...         ...
# 4995   13/6/2025          25          12  289.63          347.56          60
# 4996    9/6/2025          25          11  289.63          347.56         122
# 4997   28/2/2025          25          13  289.63          347.56          85
# 4998   22/4/2025          25           7  289.63          347.56          58
# 4999  12/12/2025          25          12  289.63          347.56          72
#
# ...

# %% [markdown]
# ## Banco de dados DB_Canal_vendas
# ---

# %%
df4 = pd.DataFrame({
"Id Canal Vendas": ["1","2"],
"Canal de Vendas": ["Direta", "Distribuidor"]
})

df4
# Out:
#   Id Canal Vendas Canal de Vendas
# 0               1          Direta
# 1               2    Distribuidor

# %% [markdown]
# # Bando de dados DB_UF
#
# ---

# %%
# Read the CSV file
DB_UF = pd.read_csv("https://raw.githubusercontent.com/leogermani/estados-e-municipios-ibge/refs/heads/master/estados.csv")

# View the first 5 rows
DB_UF

DB_UF = DB_UF.rename(columns={'COD': 'Cod UF', 'NOME':'Estado', "SIGLA":"UF"})
DB_UF
# Out:
#     Cod UF               Estado   UF
# 0       35            São Paulo   SP
# 1       41               Paraná   PR
# 2       42       Santa Catarina   SC
# 3       43    Rio Grande do Sul   RS
# 4       50   Mato Grosso do Sul   MS
# 5       11             Rondônia   RO
# 6       12                 Acre   AC
# 7       13             Amazonas   AM
# 8       14              Roraima   RR
# 9       15                 Pará   PA
# 10      16                Amapá   AP
# 11      17            Tocantins   TO
# 12      21             Maranhão   MA
# 13      24  Rio Grande do Norte   RN
# 14      25              Paraíba   PB
# 15      26           Pernambuco   PE
# 16      27              Alagoas   AL
# 17      28              Sergipe   SE
# 18      29                Bahia   BA
# 19      31         Minas Gerais   MG
# 20      33       Rio de Janeiro   RJ
# 21      51          Mato Grosso   MT
# 22      52                Goiás   GO
# 23      53     Distrito Federal   DF
# ...

# %% [markdown]
# ## Banco de dados DB_Cliente
#
# ---

# %%
random.seed(2025)
df5 = pd.DataFrame({
"Id Cliente": list(range(1, 19)),
"Cliente": ["Sabor & Arte" ,"Delícias da Terra" ,"Essência Gourmet" ,"Prato Perfeito" ,"Alma do Sabor" ,
                    "Casa do Macarrão" ,"Ovo de Ouro" ,"Carnes Nobres" ,"Sabores do Campo" ,"Riqueza do Paladar" ,
                     "Chef do Campo" ,"Macarrão Magia" ,"Tesouros da Mesa" ,"Requinte & Sabor" ,"Grãos & Alimentos" ,
                     "Harmonia Culinária" ,"Ovo Empório" ,"Carne & Cia"],
})

df5["Cod UF"] = [random.choice(DB_UF["Cod UF"]) for x in range(len(df5["Cliente"]))]

df5
# Out:
#     Id Cliente             Cliente  Cod UF
# 0            1        Sabor & Arte      28
# 1            2   Delícias da Terra      42
# 2            3    Essência Gourmet      33
# 3            4      Prato Perfeito      32
# 4            5       Alma do Sabor      26
# 5            6    Casa do Macarrão      11
# 6            7         Ovo de Ouro      27
# 7            8       Carnes Nobres      35
# 8            9    Sabores do Campo      17
# 9           10  Riqueza do Paladar      21
# 10          11       Chef do Campo      29
# 11          12      Macarrão Magia      13
# 12          13    Tesouros da Mesa      42
# 13          14    Requinte & Sabor      21
# 14          15   Grãos & Alimentos      21
# 15          16  Harmonia Culinária      43
# 16          17         Ovo Empório      41
# 17          18         Carne & Cia      43

# %% [markdown]
# ## Banco de dados DB_Vendedor
# ---

# %%
DB_Vendedor = pd.DataFrame({
"Id Vendedor": list(range(1, 11)),
"Vendedor": ["Ana Beatriz","Lucas Gabriel","Mariana Oliveira","Pedro Henrique",
             "Júlia Fernandes", "Rafael Costa","Camila Souza","Leonardo Almeida",
             "Gabriela Lima","Felipe Santos"]
})


DB_Vendedor
# Out:
#    Id Vendedor          Vendedor
# 0            1       Ana Beatriz
# 1            2     Lucas Gabriel
# 2            3  Mariana Oliveira
# 3            4    Pedro Henrique
# 4            5   Júlia Fernandes
# 5            6      Rafael Costa
# 6            7      Camila Souza
# 7            8  Leonardo Almeida
# 8            9     Gabriela Lima
# 9           10     Felipe Santos

# %% [markdown]
# ## Banco de dados DB_Produto
# ---

# %%
DB_Produto = pd.DataFrame({
"Id Produto": list(range(1, 26)),
"Produto": ["Suína", "Frango", "Bovina", "Peixe", "Camarão",
            "Aveia", "Farinha de trigo", "Soja", "Arroz", "Milho",
            "Maçã", "Melancia", "Limão", "Maracujá", "Banana",
            "Alface", "Abobrinha", "pepino", "Berinjela", "Tomate",
            "Refrigerante", "Energético", "Cerveja", "Suco", "Vinho"],
"Id Categoria": [1]*5 + [2]*5 + [3]*5 + [4]*5 + [5]*5
})


DB_Produto
# Out:
#     Id Produto           Produto  Id Categoria
# 0            1             Suína             1
# 1            2            Frango             1
# 2            3            Bovina             1
# 3            4             Peixe             1
# 4            5           Camarão             1
# 5            6             Aveia             2
# 6            7  Farinha de trigo             2
# 7            8              Soja             2
# 8            9             Arroz             2
# 9           10             Milho             2
# 10          11              Maçã             3
# 11          12          Melancia             3
# 12          13             Limão             3
# 13          14          Maracujá             3
# 14          15            Banana             3
# 15          16            Alface             4
# 16          17         Abobrinha             4
# 17          18            pepino             4
# 18          19         Berinjela             4
# ...

# %% [markdown]
# ## DB_Categoria
#
# ---

# %%
DB_Categoria = pd.DataFrame({
"Id Categoria": list(range(1, 6)),
"Categoria": ["Carne","Sereal","Fruta","Legume","bebida"],
})

DB_Categoria
# Out:
#    Id Categoria Categoria
# 0             1     Carne
# 1             2    Sereal
# 2             3     Fruta
# 3             4    Legume
# 4             5    bebida

# %% [markdown]
# ## Banco de dados DB_Metas
#
# ---

# %%
# Criar uma série de datas de 1º de janeiro a 31 de dezembro de 2025
datas_2025 = pd.date_range(start="2025-01-01", end="2025-12-31", freq='D')

# Criar um DataFrame com essas datas
datas_2025 = pd.DataFrame({'data': datas_2025})


for i in range(len(datas_2025)):
  random.seed(2025+i)
  test = pd.DataFrame({"Data": [datas_2025['data'].dt.strftime('%d/%m/%Y').tolist()[i]]*(len(DB_Vendedor["Id Vendedor"])),
                       "Id Vendedor": DB_Vendedor["Id Vendedor"],
                       "Meta": [round(random.randint(1000, 55000)) for x in range(len(DB_Vendedor["Id Vendedor"]))]
                       })

  if i >= 1:
          DB_Metas = pd.concat([DB_Metas, test],
                    axis = 0,
                    ignore_index = True,
                    sort = False)
  else:
     DB_Metas = test

DB_Metas
# Out:
#             Data  Id Vendedor   Meta
# 0     01/01/2025            1  37552
# 1     01/01/2025            2   6419
# 2     01/01/2025            3  43326
# 3     01/01/2025            4  32300
# 4     01/01/2025            5  12356
# ...          ...          ...    ...
# 3645  31/12/2025            6  23025
# 3646  31/12/2025            7  16282
# 3647  31/12/2025            8  31758
# 3648  31/12/2025            9  20470
# 3649  31/12/2025           10  38674
#
# [3650 rows x 3 columns]
